# %%
# %matplotlib notebook
from crisPy2.visu import SpectralViewer

# %%
SpectralViewer(["examples/2014/crisp_l2_20140906_152724_8542_r00447.fits", "examples/2014/crisp_l2_20140906_152724_6563_r00447.fits"])
# Out:
# <img src="data:image/png;base64,..." width="800">
# interactive(children=(SelectionSlider(description='Ca II Δ λ [Å]', options=(<Quantity -1.2 Angstrom>, <Quantit…
# ...
